# %% [markdown]
# # Module 1 : Welcome to this course ! (15 mins)
#            a.. Introduction & course benefits ! 3 mins
#            b.. Pre-requisites (Installing R in Jupyter notebook & Set-up) - 7 min
#            c.. Quick Summary of Jupyter Notebook - 5 min

# %% [markdown]
# ## a.. Introduction & course benefits ! 3 mins

# %% [markdown]
# ## b.. Pre-requisites (Installing R in Jupyter notebook & Set-up) - 7 min

# %%
## b.. Pre-requisites (Installing R in Jupyter notebook & Set-up) - 7 min

## first show installing of Anaconda navigator !
## Then explain what is virtual environment !

## Then show how to install R in Jupyter Notebook ! ( Refer R_in_Anaconda_with_latest_version.txt)

## Show how to open Jupyter notebook !
## Then show how to open Jupyter notebook at other directories !

# %% [markdown]
# ## c.. Quick Summary of Jupyter Notebook - 5 min

# %% [markdown]
# # Module 2 : About dplyr ( 10 mins)
#               a.. what is dplyr ?? : 5 mins
#               b.. when to use dplyr & how to install it ?? : 5 mins

# %% [markdown]
# ## a.. what is dplyr ??
#
#     dplyr is equivalent to Pandas in Python
#
#     dplyr is a package
#     U might ask what are packages or library  ?
#     So library is a collection of functions and tools bundled together for a specific purpose..
#
#     The dplyr package is one of the most powerful and popular package in R.
#     This package was written by the most popular R programmer Hadley Wickham who has written many useful R packages
#     such as ggplot2, tidyr etc
#
#     Dplyr is used primarily for manipulating , cleaning and transforming data ,ie in short ,
#     it makes data exploration and data manipulation easy and fast in R.

# %% [markdown]
# ## b.. when to use dplyr & how to install it ??

# %% [markdown]
#     ->> Using dplyr versus base R functions depends on your preferences, the complexity of your data manipulation tasks
#         and the readability of your code..
#
#         What is base-R ?
#         base-R(moment u install R in your system , then default functions that comes with u often known as base-R functions)
#
#
#     ->> dplyr code tends to be more readable and expressive, making it easier to understand the data manipulation steps..
#         The syntax of dplyr functions is designed to be intuitive, more like English language..
#
#
#     ->> When to use base-R command or dplyr code ?
#         Simple Rule of thumb is :
#             If your dplyr code has better code readibility , use dplyr code
#             If your base-R code has better code readibility , use base-R

# %%
### to install it
install.packages("dplyr")

### To load dplyr package, type the command below
library(dplyr)

# %% [markdown]
# # Module 3 : basic data structures of R ( vector , list , dataframe) : 23 mins
#                 a.. basics of vector data-structure ! ( 6 mins)
#                 b.. basics of list ! ( 6 mins)
#                 c.. basics of data-frame ! (8 mins)
#                 d.. reading csv file : 3 mins

# %%
"

Data structures : Its all about efficient way of storing data..

"

# %% [markdown]
# ## a.. basics of vector data-structure !

# %% [markdown]
#     list & vector are 2 different classes in R..
#
#     List in Python -~ vector in R
#     closest thing to python dict is simply R list
#
#
#
#     Imagine I want to compute mean of some set of numbers : (3 , 5 , 8 , 6 , 8)
#     First we have store these numbers so that we can compute mean !
#     As it is numerical data & since it is a 1-D data , ie we can use vector data structure to store these nu,bers ...
#
#
#         Vectors : 1D data structure , more like array for those of you who are from C/Java background...
#             (collection of same data-type)
#             All the values in a vector must have the same type (numeric, character, or logical)..
#             A vector is an object that contains a set of same type of values called its elements..
#
#             X = c(1, 3, 5, 7, 8)
#             e.g , c = used for concatenation / combine / concatenate / convert / coerce function..
# https://www.computerworld.com/article/2497319/business-intelligence-beginner-s-guide-to-r-syntax-quirks-you-ll-want-to-know.html
#
#              To put multiple values into a single variable, you use the c() function, such as:
#              X = c(1, 3, 5, 7, 8)
#
#              In R , we could have :
#
#             "numeric vector" = c(1 , 3 , 4 , 5)
#             "character vector" = c("shan" , "singh" , "tanu")
#             "logical vector" = c(TRUE , FALSE , TRUE )

# %%
## One more important point about the c() function: 
## It assumes that everything in your vector is of the same data type — 
## that is, all numbers or all characters. 
## If you create a vector such as:

my_vector = c(1 , 4 , "hello", TRUE)

my_vector
# Out:
# [1] "1"     "4"     "hello" "TRUE"

# %%
## You will not have a vector with two integer objects, one character object and one logical object.
## Instead, What c() will do : 
## it will convert all into same object type, in this case all character objects.
## ie here , c works as convert or coerce..

# %% [markdown]
# ## b.. basics of list !
#         Collection of multiple key:value pairs

# %%
## To create a collection with multiple object types, you need an R list, not a vector
## You create a list with the list() function, not c(), such as:

My_list = list(1 , 4 , "hello" , TRUE)

# %%
My_list

### ie for key1 , we have value as 1
### ie for key2 , we have value as 4

### ie , List is a Collection of multiple key:value pairs
# Out:
# [[1]]
# [1] 1
#
# [[2]]
# [1] 4
#
# [[3]]
# [1] "hello"
#
# [[4]]
# [1] TRUE

# %%
### Imagine Facebook wants to store multiple users Fb profile data , 
### then Programmers have to use list data-structure to store it..

# %%
### Lists(collection of multiple objects[Integer , char , logical] or 
### diff. data-type or collection of vectors)
### Its a (1D data structure)

# %%
Pro_Id = c(1, 2, 3, 4)
name = c("Shan", "Sandeep", "John", "Warner")
Interests = c("Teaching" , "dancing" , "Coding" , "Travelling")

fb_data = list(Pro_Id, name, Interests)


### empList = list(c(1, 2, 3, 4) , c("Shan", "Sandeep", "John", "Warner") , c("Teaching" , "dancing" , "Coding" , "Travelling"))
### empList <-list(c(1, 2, 3, 4) , c("Shan", "Sandeep", "John", "Warner") , c("Teaching" , "dancing" , "Coding" , "Travelling"))

# %%
fb_data
# Out:
# [[1]]
# [1] 1 2 3 4
#
# [[2]]
# [1] "Shan"    "Sandeep" "John"    "Warner"
#
# [[3]]
# [1] "Teaching"   "dancing"    "Coding"     "Travelling"

# %% [markdown]
# ### Naming list elements :
#      ie assign features to list..
#      ie , list elements can be given names and they can be accessed using these names.

# %%
Pro_Id = c(1, 2, 3, 4)
name = c("Shan", "Sandeep", "John", "Warner")
Interests = c("Teaching" , "dancing" , "Coding" , "Travelling")

fb_data2 = list(Profile_id = Pro_Id, Profile_name = name , Interests = Interests)

### names(empList2) <- c("Profile_id", "Profile_name", "Interests")

# %%
fb_data2
# Out:
# $Profile_id
# [1] 1 2 3 4
#
# $Profile_name
# [1] "Shan"    "Sandeep" "John"    "Warner"
#
# $Interests
# [1] "Teaching"   "dancing"    "Coding"     "Travelling"

# %%
"

ie R List is a collection of (key-value pairs)

"

# %% [markdown]
# ## c.. basics of data-frame !

# %% [markdown]
#     dataframe is all about collection of vectors
#     as Each column in a data frame is essentially a vector..
#
#     you can think of an R data frame as an extension of an R list..
#     Key of list will be col of dataframe & values of list will be values of column

# %%
### moment u call data.frame() , ie u can trying to create a obj of data.frame class...

# %%
df_fb = data.frame(fb_data2)

# %%
df_fb
# Out:
#   Profile_id Profile_name Interests
# 1 1          Shan         Teaching
# 2 2          Sandeep      dancing
# 3 3          John         Coding
# 4 4          Warner       Travelling

# %% [markdown]
# #### what is Dataframe ??
#     Its all about data in the form of Rows & colums , ie It is exactly equal to csv data (excel)
#     If you're familiar with the Table in Excel then you already have a grasp of what a R dataframe is.
#     It's a table of data. It has rows and columns
#     Its 2-D data structure
#     Its like a Table or a matrix
#
#     If we see internally , implementation of R dataframe is all about ' Sequence/collection of vector '
#
#
#     From Programming - point of view , we have data-structure called List..
#     It is just a extension of List (data-structure of R)
#     e.g->> l1 = list(first_name = c('Shan' , 'Rahul') ,
#                       last_name = c('Singh' , 'Singh')
#                   )
#     ie , R Dataframe is exactly a extended form of R List(key-value pairs) , key becomes feature/col & value becomes rows..
#
#
#     Dataframe are size-mutable,  heterogeneous tabular data
#
#      R DataFrame will be created by loading the data sets from various storage:
#      storage can be SQL Database, .CSV file,json,flat files and Excel file.
#      R DataFrame can also be created internally from the list, R etc.

# %% [markdown]
# ### Accessing columns of a dataframe :

# %% [markdown]
#         Single bracket [ ] = returns output in dataframe
#         Double bracket [[ ]] = returns output in vector
#         Dollar Sign"$" = returns output in vector

# %%
### R has main 3 indexing operators.. "[ ]" , "[[ ]]" , "$"

# %%
df_fb$Profile_name

### returns vector 
### ie , 1-D data structure , where All the values must have the same type 
### (numeric, character, or logical).

# %%
df_fb[["Profile_name"]] ### returns vector

# %%
df_fb["Profile_name"] ## returns data-frame

# %% [markdown]
# ## d.. reading csv file

# %%
args(read.csv)
# Out:
# function (file, header = TRUE, sep = ",", quote = "\"", dec = ".",
#     fill = TRUE, comment.char = "", ...)
# NULL

# %%
help(read.csv)

### Reads a file in table format and creates a data frame from it

# %%
"

Parameters:

file : The path to the CSV file to be read.
header : A logical value indicating whether the file contains 
         the names of the variables as the first line (header). 
         Default is TRUE.
sep : The separator character used in the CSV file. Default is ","
quote : The character used to enclose fields that contain special characters, 
        such as commas or line breaks. 
        Default is "\""
dec : The character used in the file for decimal points. Default is "." ..
fill : A logical value indicating whether to fill missing fields with NA. Default is TRUE.
comment.char : The character used to indicate comments in the file. Default is an empty string.
... : Additional arguments to be passed to read.table().



"

# %%
df = read.csv("R:/Entire_R_Data_Analysis/8.. R_basic_courses/1.. R_Free_course/
              hotel_booking_sample.csv")

# %%
df
# Out:
#       hotel        is_canceled lead_time arrival_date_year arrival_date_month
# 1     City Hotel   0            62       2016              September
# 2     City Hotel   1           364       2015              October
# 3     City Hotel   0             3       2016              February
# 4     City Hotel   1           381       2016              December
# 5     City Hotel   1           281       2017              August
# 6     City Hotel   0            20       2016              September
# 7     City Hotel   0           317       2017              June
# 8     City Hotel   0             4       2016              February
# 9     City Hotel   1            28       2016              June
# 10    Resort Hotel 1           102       2017              February
# 11    City Hotel   0           109       2017              March
# 12    Resort Hotel 0            11       2015              July
# 13    City Hotel   1            61       2017              May
# ...

# %% [markdown]
#     In context of above dataframe , u can treat every column as a vector..
#     ie , dataframe is all about sequence/collection of vectors..
#
#     In context of above dataframe , u can treat above dataframe as a extension of list , here key of list becomes col of
#     dataframe & value of list becomes values of col

# %% [markdown]
# # Module 4 : Interesting things in dplyr  (7 mins)
#           a.. Pipe operator (%>%) in dplyr or [chaining in R] : 3 mins
#           b.. "double colon" operator in R : 4 mins

# %% [markdown]
# ## a.. Pipe operator (%>%) in dplyr or [chaining in R]

# %%
df
# Out:
#       hotel        is_canceled lead_time arrival_date_year arrival_date_month
# 1     City Hotel   0            62       2016              September
# 2     City Hotel   1           364       2015              October
# 3     City Hotel   0             3       2016              February
# 4     City Hotel   1           381       2016              December
# 5     City Hotel   1           281       2017              August
# 6     City Hotel   0            20       2016              September
# 7     City Hotel   0           317       2017              June
# 8     City Hotel   0             4       2016              February
# 9     City Hotel   1            28       2016              June
# 10    Resort Hotel 1           102       2017              February
# 11    City Hotel   0           109       2017              March
# 12    Resort Hotel 0            11       2015              July
# 13    City Hotel   1            61       2017              May
# ...

# %%
head(df , 2)
# Out:
#   hotel      is_canceled lead_time arrival_date_year arrival_date_month
# 1 City Hotel 0            62       2016              September
# 2 City Hotel 1           364       2015              October
#   arrival_date_week_number arrival_date_day_of_month stays_in_weekend_nights
# 1 40                       27                        0
# 2 42                       16                        0
#   stays_in_week_nights adults ... deposit_type agent company
# 1 3                    2      ... No Deposit   14    NULL
# 2 2                    2      ... Non Refund   6     NULL
#   days_in_waiting_list customer_type   adr   required_car_parking_spaces
# 1 0                    Transient       125.1 0
# 2 0                    Transient-Party 101.5 0
#   total_of_special_requests reservation_status reservation_status_date
# 1 0                         Check-Out          9/30/2016
# 2 0                         Canceled           7/6/2015

# %%
library(dplyr)

# %%
df %>% head(2)

### on top of "df" dataframe , apply head() to fetch first few instances :
# Out:
#   hotel      is_canceled lead_time arrival_date_year arrival_date_month
# 1 City Hotel 0            62       2016              September
# 2 City Hotel 1           364       2015              October
#   arrival_date_week_number arrival_date_day_of_month stays_in_weekend_nights
# 1 40                       27                        0
# 2 42                       16                        0
#   stays_in_week_nights adults ... deposit_type agent company
# 1 3                    2      ... No Deposit   14    NULL
# 2 2                    2      ... Non Refund   6     NULL
#   days_in_waiting_list customer_type   adr   required_car_parking_spaces
# 1 0                    Transient       125.1 0
# 2 0                    Transient-Party 101.5 0
#   total_of_special_requests reservation_status reservation_status_date
# 1 0                         Check-Out          9/30/2016
# 2 0                         Canceled           7/6/2015

# %% [markdown]
# ## b..  "double colon"(::) operator in R

# %% [markdown]
#     It is especially important when u are working with multiple packages to prevent overwriting of functions
#     or if u have same function name from different packages..
#
#     So just to get rid of confusion  , u can use this :: to avoid confusion
#     dplyr :: group_by()
#     Syntax -> dplyr :: function()
#
#     Or if u want to maintain more readibility  , u can say this function belongs to this specific package , ie :
#
#     dplyr :: group_by()
#     Syntax -> dplyr :: function()

# %% [markdown]
# # Module 5 : Filtering and Selecting Data (25 minutes)
#           a.. Selecting specific columns using select() : 5 mins
#           b.. Dropping specific columns using select() : 5 mins
#           c.. Basic filtering using filter() : 5 mins
#           d.. filtering rows & columns
#           e.. Dealing with duplicate rows : 5 mins

# %% [markdown]
# ## a.. Selecting specific columns using select()

# %%
names(df)
# Out:
#  [1] "hotel"                          "is_canceled"
#  [3] "lead_time"                      "arrival_date_year"
#  [5] "arrival_date_month"             "arrival_date_week_number"
#  [7] "arrival_date_day_of_month"      "stays_in_weekend_nights"
#  [9] "stays_in_week_nights"           "adults"
# [11] "children"                       "babies"
# [13] "meal"                           "country"
# [15] "market_segment"                 "distribution_channel"
# [17] "is_repeated_guest"              "previous_cancellations"
# [19] "previous_bookings_not_canceled" "reserved_room_type"
# [21] "assigned_room_type"             "booking_changes"
# [23] "deposit_type"                   "agent"
# [25] "company"                        "days_in_waiting_list"
# [27] "customer_type"                  "adr"
# [29] "required_car_parking_spaces"    "total_of_special_requests"
# [31] "reservation_status"             "reservation_status_date"

# %%
args(select)
# Out:
# function (.data, ...)
# NULL

# %%
help(select)

### Keep or drop columns using their names and types

# %%
"

Overview of selection features :

We can use below approaches to select cols : 

    : for selecting a range of consecutive variables.

    ! for taking the complement of a set of variables.

    & and | for selecting the intersection or the union of two sets of variables.

    c() for combining selections..



We have other ways to select cols , do refer : help(select)

"

# %% [markdown]
#     .data : This is the primary argument and represents the data frame or tibble from which you want to select columns.
#
#     ... : The ellipsis (...) means I can pass additional arguments..
#           In the case of select() , I have to mention expressions specifying which columns to select or drop..

# %%
### here we will use : c() for combining selections.. to  filter cols

# %%
select(df, c('hotel' , 'is_canceled' , 'lead_time'))

### select these cols : c('hotel' , 'is_canceled' , 'lead_time') from "df" dataframe

# %%
### using chain(pipe) operator : provides more readibility 
df %>% select(c('hotel' , 'is_canceled' , 'lead_time'))

### on top of "df" dataframe , apply select() to select specific cols :

# %% [markdown]
# ## b.. Dropping specific columns using select() :

# %%
names(df)
# Out:
#  [1] "hotel"                          "is_canceled"
#  [3] "lead_time"                      "arrival_date_year"
#  [5] "arrival_date_month"             "arrival_date_week_number"
#  [7] "arrival_date_day_of_month"      "stays_in_weekend_nights"
#  [9] "stays_in_week_nights"           "adults"
# [11] "children"                       "babies"
# [13] "meal"                           "country"
# [15] "market_segment"                 "distribution_channel"
# [17] "is_repeated_guest"              "previous_cancellations"
# [19] "previous_bookings_not_canceled" "reserved_room_type"
# [21] "assigned_room_type"             "booking_changes"
# [23] "deposit_type"                   "agent"
# [25] "company"                        "days_in_waiting_list"
# [27] "customer_type"                  "adr"
# [29] "required_car_parking_spaces"    "total_of_special_requests"
# [31] "reservation_status"             "reservation_status_date"

# %%
updated_df = df %>% select(-c('agent' , 'company'))

### - tells R to exclude these features..
### If u want to store this updated dataframe , u have to store it into new_var , let say as"updated_df"

# %%
head(updated_df , 2)
# Out:
#   hotel      is_canceled lead_time arrival_date_year arrival_date_month
# 1 City Hotel 0            62       2016              September
# 2 City Hotel 1           364       2015              October
#   arrival_date_week_number arrival_date_day_of_month stays_in_weekend_nights
# 1 40                       27                        0
# 2 42                       16                        0
#   stays_in_week_nights adults ... assigned_room_type booking_changes
# 1 3                    2      ... A                  0
# 2 2                    2      ... A                  0
#   deposit_type days_in_waiting_list customer_type   adr
# 1 No Deposit   0                    Transient       125.1
# 2 Non Refund   0                    Transient-Party 101.5
#   required_car_parking_spaces total_of_special_requests reservation_status
# 1 0                           0                         Check-Out
# 2 0                           0                         Canceled
#   reservation_status_date
# ...

# %% [markdown]
# ## c.. Basic filtering using filter() :

# %%
names(df)
# Out:
#  [1] "hotel"                          "is_canceled"
#  [3] "lead_time"                      "arrival_date_year"
#  [5] "arrival_date_month"             "arrival_date_week_number"
#  [7] "arrival_date_day_of_month"      "stays_in_weekend_nights"
#  [9] "stays_in_week_nights"           "adults"
# [11] "children"                       "babies"
# [13] "meal"                           "country"
# [15] "market_segment"                 "distribution_channel"
# [17] "is_repeated_guest"              "previous_cancellations"
# [19] "previous_bookings_not_canceled" "reserved_room_type"
# [21] "assigned_room_type"             "booking_changes"
# [23] "deposit_type"                   "agent"
# [25] "company"                        "days_in_waiting_list"
# [27] "customer_type"                  "adr"
# [29] "required_car_parking_spaces"    "total_of_special_requests"
# [31] "reservation_status"             "reservation_status_date"

# %%
unique(df$hotel)
# Out:
# [1] "City Hotel"   "Resort Hotel" NA

# %%
help(filter)

## Keep rows that match a condition

# %%
"

There are many functions and operators that are useful to filter the rows : 

==, >, >= etc

&, |, !, xor()

is.na()

between(), near()

"

# %%
args(filter)
# Out:
# function (.data, ..., .by = NULL, .preserve = FALSE)
# NULL

# %% [markdown]
#     .data: This is the primary argument and represents the data frame or tibble you want to filter.
#
#     ...: The ellipsis (...) allows you to pass additional arguments that modify the behavior of the function.
#         In the case of filter() , you would typically pass conditions based on columns in the data frame.

# %%
dplyr :: filter(df , df$hotel == 'City Hotel' ) ## extracting all data of 'City Hotel' 

## df %>% dplyr :: filter(df$hotel == 'City Hotel')
## ie on top of "df" , let's apply filter function to filter rows where hotel == 'City Hotel'
# Out:
#      hotel      is_canceled lead_time arrival_date_year arrival_date_month
# 1    City Hotel 0            62       2016              September
# 2    City Hotel 1           364       2015              October
# 3    City Hotel 0             3       2016              February
# 4    City Hotel 1           381       2016              December
# 5    City Hotel 1           281       2017              August
# 6    City Hotel 0            20       2016              September
# 7    City Hotel 0           317       2017              June
# 8    City Hotel 0             4       2016              February
# 9    City Hotel 1            28       2016              June
# 10   City Hotel 0           109       2017              March
# 11   City Hotel 1            61       2017              May
# 12   City Hotel 0            18       2017              July
# 13   City Hotel 0            84       2017              March
# 14   City Hotel 1           393       2016              March
# ...

# %% [markdown]
# ## d.. filtering rows & columns

# %%
names(df)
# Out:
#  [1] "hotel"                          "is_canceled"
#  [3] "lead_time"                      "arrival_date_year"
#  [5] "arrival_date_month"             "arrival_date_week_number"
#  [7] "arrival_date_day_of_month"      "stays_in_weekend_nights"
#  [9] "stays_in_week_nights"           "adults"
# [11] "children"                       "babies"
# [13] "meal"                           "country"
# [15] "market_segment"                 "distribution_channel"
# [17] "is_repeated_guest"              "previous_cancellations"
# [19] "previous_bookings_not_canceled" "reserved_room_type"
# [21] "assigned_room_type"             "booking_changes"
# [23] "deposit_type"                   "agent"
# [25] "company"                        "days_in_waiting_list"
# [27] "customer_type"                  "adr"
# [29] "required_car_parking_spaces"    "total_of_special_requests"
# [31] "reservation_status"             "reservation_status_date"

# %%
df %>% dplyr :: filter(df$hotel == 'City Hotel') %>% select(c('hotel' , 'is_canceled' , 'lead_time' , 'arrival_date_year'))

# %% [markdown]
# ## e.. Dealing with duplicate rows :

# %%
class(duplicated(df)) ## returns logical(boolean) vector ie True/False or 0/1 vector
# Out:
# [1] "logical"

# %%
duplicated(df)

## "TRUE" means : We have duplicated instance at that row-index 
## "FALSE" means : We do not have duplicated instance at that row-index
# Out:
#     [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [61] FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [133] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
df %>% dplyr :: filter(duplicated(df))  ## detection of duplicate rows

## The rows selected are the ones where duplicated(df) is TRUE
# Out:
#      hotel        is_canceled lead_time arrival_date_year arrival_date_month
# 1    City Hotel   1           186       2017              May
# 2    City Hotel   1           322       2016              December
# 3    City Hotel   0           134       2017              February
# 4    City Hotel   0           134       2017              February
# 5    City Hotel   1            37       2016              October
# 6    City Hotel   1           379       2015              October
# 7    City Hotel   1           186       2017              May
# 8    City Hotel   1            80       2017              March
# 9    City Hotel   1           301       2015              August
# 10   Resort Hotel 1           259       2015              September
# 11   City Hotel   0           377       2016              October
# 12   City Hotel   1           169       2017              June
# 13   City Hotel   1           247       2016              October
# ...

# %%
help(distinct)

## Keep only unique/distinct rows from a data frame

# %%
args(dplyr :: distinct)
# Out:
# function (.data, ..., .keep_all = FALSE)
# NULL

# %% [markdown]
#      .data = data frame or tibble from which to select distinct rows..
#
#     .keep_all : parameter that controls whether to keep all columns or only those used for identifying distinct rows..
#                 The default value is FALSE..

# %%
### if u want to drop duplicate rows 
data = dplyr :: distinct(df)

# %% [markdown]
# # Module 6 : Sorting and Mutating Data (10 mins)
#          a.. Sorting data using arrange() : 5 mins
#          b.. Creating and modifying columns with mutate() : 5 mins

# %% [markdown]
# ## a.. Sorting data using arrange() :

# %%
help(arrange)

### orders the rows of a data frame by the values of selected columns..

# %%
"

function (.data, ..., .by_group = FALSE)
    .data : dataframe on which we are working 
    ... :  <data-masking> Variables, or functions of variables. Use desc() to sort a variable in descending order

"

# %%
args(arrange)
# Out:
# function (.data, ..., .by_group = FALSE)
# NULL

# %%
### Suppose you need to sort "adr" in a descending order
dplyr :: arrange(df , desc(adr))

## df %>% arrange(desc(adr))
# Out:
#       hotel        is_canceled lead_time arrival_date_year arrival_date_month
# 1     City Hotel   0            81       2016              December
# 2     Resort Hotel 1           319       2016              December
# 3     Resort Hotel 0            16       2017              August
# 4     Resort Hotel 1            23       2017              July
# 5     Resort Hotel 1            20       2017              July
# 6     Resort Hotel 0            18       2016              August
# 7     Resort Hotel 0            14       2016              August
# 8     Resort Hotel 1            28       2017              July
# 9     Resort Hotel 0            16       2016              August
# 10    Resort Hotel 1           360       2017              August
# 11    Resort Hotel 0             2       2016              August
# 12    City Hotel   0             2       2017              June
# 13    Resort Hotel 0           144       2016              August
# ...

# %% [markdown]
# ## b.. Creating new columns with mutate() :

# %%
help(mutate)

### Create, modify, and delete columns
### In general  , it is used for cols creation !

# %%
args(mutate)
# Out:
# function (.data, ...)
# NULL

# %% [markdown]
#     .data: This is the primary argument and represents the data frame or tibble you want to modify.
#
#     ... : The ellipsis (...) means , I can pass additional arguments.
#           In the case of mutate(), you would typically pass expressions that define the new columns or modify existing ones

# %%
mutate(df , Total_Guests = adults + children + babies) ## Total guests arrival

# %%
df = df %>% mutate(Total_Guests = adults + children + babies) ## Total guests arrival

# %% [markdown]
# # Module 7 : Summarizing and Grouping Data (30 minutes)
#           a.. Understanding internals of group_by : 7 mins
#           b.. Grouping data with group_by() : 7 mins
#           c.. Combining operations with piping (%>%) : 6 mins
#           d.. understanding tibble data-structure : 10 mins

# %% [markdown]
# ## a.. Understanding internals of group_by

# %% [markdown]
#     we can think of groupby as ->> Split , apply , combine
#     ie first we split data into groups , then we apply some function(agg func like mean , etc) & then we combine results

# %%
### https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html--must follow

# %% [markdown]
# ## we can think groupby as -->> Split, apply, combine
#
# https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
#
# https://www.analyticsvidhya.com/blog/2020/03/understanding-transform-function-python/ -->> for understanding backend of groupby
#
# https://pandas.pydata.org/docs/user_guide/groupby.html#groupby

# %% [markdown]
# ## b.. Grouping data with group_by()

# %%
help(summarise)

# %%
"

summarise() creates a new data frame..
It returns one value/row for each combination of grouping variables ;
                    OR
It returns one value for every sub-category in grouping variables ;
eg avg price of category col

o/p :
Cloth   34.56
biscuit 12.34
chips   34.56



if there are no grouping variables, the output will have a single value which is summarising rows of a column..

"

# %%
args(summarise)
# Out:
# function (.data, ..., .by = NULL, .groups = NULL)
# NULL

# %% [markdown]
#     .data : data frame or tibble you want to summarize..
#
#     ... : The ellipsis (...) means I can pass additional arguments,
#           which are typically expressions that define the new columns or summary statistics you want to calculate..

# %%
help(group_by)

### Group by one or more variables

# %%
args(group_by)
# Out:
# function (.data, ..., .add = FALSE, .drop = group_by_drop_default(.data))
# NULL

# %% [markdown]
#     .data: This is the data frame that you want to group.
#             It represents the dataset on which u want to apply groupby()
#
#     ...: The ellipsis (...) is a placeholder for additional arguments.
#         In the case of group_by(), it allows you to specify the grouping columns.
#         You can provide column names, expressions, or functions that generate the grouping variables.
#
#     .add: This argument is optional.
#         If set to TRUE, it adds the grouping information to the existing groups.
#         If set to FALSE (the default), it replaces the existing groups with the new grouping information.
#
#     .drop: This argument is optional. It specifies whether to drop groups that have no data.
#         The default behavior is determined by the group_by_drop_default() function.

# %%
gdf = dplyr :: group_by(df , arrival_date_month)

# %%
dplyr :: summarise(gdf, total_guests = sum(Total_Guests))

### Which month have maximum number of guests ?
# Out:
#    arrival_date_month total_guests
# 1  April              2287
# 2  August               NA
# 3  December           1355
# 4  February           1605
# 5  January            1013
# 6  July               2752
# 7  June               2199
# 8  March              1847
# 9  May                2221
# 10 November           1110
# 11 October            2069
# 12 September          1994

# %% [markdown]
# ## c.. understanding tibble data-structure !

# %%
class(gdf)
# Out:
# [1] "grouped_df" "tbl_df"     "tbl"        "data.frame"

# %%
"


grouped_df: This suggests that "gdf" is likely a grouped data frame. 
            In R, a grouped data frame typically means that the data has been grouped by one or more variables, 
            and operations will be applied within those groups.



"tbl_df" and "tbl": 
tbl_df' and 'tbl' are related to tibble package , they are almost similar to data frames but with some enhancements, 
such as improved printing and handling of column types..

So If you are working within the tidyverse ecosystem, especially with packages like "dplyr" or "ggplot2" , 
the resulting data structure may be treated as a 'tbl_df' or 'tbl' because these packages often return data frames as tibbles 
to take advantage of their enhanced features..


        ie In R, "tbl_df" is a subclass of "tbl." 
        By the way "tbl_df" and "tbl" are classes provided by the tibble package , 
        which is an extension of the data frame class in R.



data.frame: 
If you are working with base R functions or other packages that do not use tibbles, 
then data structure may be treated as a standard 'data.frame'.


"

# %%
"

Q: if u print your data using head(data , 5) , sometimes u get tibble , sometimes u get dataframe , Why so ?

Ans : It depend on various factors, including the functions you use, the packages you load and the code u are using !

1) Some functions in R have default behavior that returns either a data.frame or a tibble.. 
   For example :
        Functions in the dplyr package, such as mutate() or filter() returns tibble by default..
        Base R functions like read.csv() or read.table() returns dataframe 

2) When you use packages like dplyr or tidyr (part of the tidyverse),  many of the functions work with tibble 


3) if you read data from a CSV file using read_csv() from the readr package, it typically returns a tibble. 
   However, if you use read.csv() from base R, it returns a data.frame


"

# %% [markdown]
# ## d.. Combining group_by operations with piping (%>%)

# %%
### Which month have maximum number of guests ?

# %%
head(df , 2)
# Out:
#   hotel      is_canceled lead_time arrival_date_year arrival_date_month
# 1 City Hotel 0            62       2016              September
# 2 City Hotel 1           364       2015              October
#   arrival_date_week_number arrival_date_day_of_month stays_in_weekend_nights
# 1 40                       27                        0
# 2 42                       16                        0
#   stays_in_week_nights adults ... agent company days_in_waiting_list
# 1 3                    2      ... 14    NULL    0
# 2 2                    2      ... 6     NULL    0
#   customer_type   adr   required_car_parking_spaces total_of_special_requests
# 1 Transient       125.1 0                           0
# 2 Transient-Party 101.5 0                           0
#   reservation_status reservation_status_date Total_Guests
# 1 Check-Out          9/30/2016               2
# 2 Canceled           7/6/2015                2

# %%
df %>% group_by(arrival_date_month) %>% summarise(total_guests = sum(Total_Guests))
# Out:
#    arrival_date_month total_guests
# 1  April              2287
# 2  August               NA
# 3  December           1355
# 4  February           1605
# 5  January            1013
# 6  July               2752
# 7  June               2199
# 8  March              1847
# 9  May                2221
# 10 November           1110
# 11 October            2069
# 12 September          1994

# %%
### August seems to have max guests !
## April , May , June , July , August have interesting numbers !

# %%
df %>% group_by(arrival_date_month) %>% summarise(mean_adr = mean(adr, na.rm = TRUE))  ## which month has highest mean adr !

# %%
df %>% group_by(arrival_date_month) %>% summarise(total_bookings = n())  ## which month has highest number of bookings !
# Out:
#    arrival_date_month total_bookings
# 1  April              1156
# 2  August             1387
# 3  December            689
# 4  February            858
# 5  January             579
# 6  July               1256
# 7  June               1100
# 8  March               964
# 9  May                1157
# 10 November            650
# 11 October            1116
# 12 September          1027
