# %%
As matplotlib is specific lib built for Data Viz.. 
Ie first & foremost , we need to load data..

In order to load data ,imagine u have a file 
in your local system..
There are 2 ways to load  this data->>

one way : u can think of using File handling in Python 
(for those of u who are phenomenal with programming)
Another way: is u can think of using in-built packages of Python ( Pandas )

# %%
Pandas is built on top of NumPy
Pandas is an open-source library in Python. 
It runs on top of NumPy and it is popularly 
used for data science and data analytics
It is primarily used for data manipulalation ,
cleaning & sometimes even for data viz...

# %% [markdown]
# ## Series ( what is series ,how to access 1 feature & about type )

# %% [markdown]
# ## dataframe ( what is dataframe & how to access 2 or more than 2 features & about type )

# %% [markdown]
# ## what is Dataframe ??
#     Its all about data in the form of Rows & colums  ,
#     ie It is exactly equal to csv data (excel)
#     If you're familiar with the Table in Excel then you already have a grasp of what a Pandas dataframe is.
#     It's a table of data.
#     It has rows and columns
#     Its 2-D data structure
#     Its like a Table or a matrix
#     If we see internally , implementation of pandas dataframe is all about ' Sequence of series '
#     ie ,if series is all about list or array
#     then dataframe is all bout lists of list..
#
#
#     From Python - point of view ,for those of u who
#      are from python background ,we have data-structure called Dictionary..
#     It is just a extension of dictionary (data-structure of python)
#     e.g->> dict1={'first_name':'Shan' ,
#                   'last_name':'Singh'
#                   }
#     in dataframe ,key becomes feature & value becomes rows..
#
#
#     Dataframe are size-mutable,  heterogeneous tabular data
#
#      Pandas DataFrame will be created by loading the
#      data sets from various storage:
#      storage can be SQL Database, .CSV file, and Excel file.
#      Pandas DataFrame can also be created internally
#      from the lists, dictionary, and from a list of dictionary etc.
#
#
#
#
#      Series & dataframe are 2 different classes in pandas.

# %% [markdown]
# ## attributes of pandas dataframe..
#     1..values -->> Return a Numpy representation of the DataFrame.
#     2..shape -->> Return a tuple representing the dimensions of the DataFrame.
#     3..dtypes-->> returns data-type of the features of a dataframe
#     4..columns-->> returns column-name of the DataFrame.
#
#     5..index -->> returns The index (row labels) of the DataFrame.
#     6..iloc -->> integer-location based indexing for selection by position.
#     7..loc -->> Access a group of rows and columns by label(s) or a boolean array.
#     8..at -->> Access a single value for a row/column label pair.
#     9..iat-->> Access a single value for a row/column pair by integer position.
#
#     10..axes -->> Return a list representing the axes of the DataFrame.
#     11..ndim -->> Return an int representing the number of axes / array dimensions.
#     12..size -->> Return an int representing the number of elements in this object.
#
#     13..empty-->> Indicator whether DataFrame is empty.
#     14..style-->> Returns a Styler object.
#     15..attrs-->> Dictionary of global attributes of this dataset.
#     16..flags-->> Get the properties associated with this pandas object.
#
#     17..T -->> returns tranpose of a dataframe..

# %%
import pandas as pd

# %%
df=pd.read_csv(r'F:\Pandas/zomato_sample.csv')
df.shape
# Out:
# (5000, 10)

# %%
df.head(2)
# Out:
#                               name online_order book_table  rate  votes  \
# 0  3B's - Buddies, Bar & Barbecues           No        Yes   NaN   1168
# 1                   New Taj Darbar           No         No   3.1      6
#
#      location           rest_type  \
# 0         BTM  Casual Dining, Bar
# 1  Whitefield         Quick Bites
#
#                                           dish_liked  \
# 0  Paan Ice Cream, Cocktails, Fish Grill, Crispy ...
# 1                                                NaN
#
#    approx_cost(for two people) listed_in(city)
# 0                       1100.0       Jayanagar
# 1                        300.0      Whitefield

# %%
### use-case of line-chart 
## (line-plot is typically used if u have to find trend within data) :

## imagine there is a feature as
dates=[]
total_orders=[]

plt.plot(dates,total_orders)

# %%
days=['sun','mon','tues','wed','thursday','fri','sat']
total_orders=[4000, 5056, 6598, 5499, 7897, 6789, 9012]

plt.plot(days,total_orders)

# %%
weekdays=[]

# %% [markdown]
# ## 4. basics plots of matplotlib

# %% [markdown]
# #### line , bar , pie , scatter ,histogram

# %% [markdown]
# ### scatter

# %%
### what is the distribution of 'rate' feature ?

# %%
### what is histogram ?
## histogram is used to show the distribution of a 
   single variable (continuous numerical ). 
    Example: Age of the Person.

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['rate'])
# Out:
# (array([   4.,   57.,  154.,  396.,  443.,  995., 1054.,  673.,  238.,
#           39.]),
#  array([2.1 , 2.38, 2.66, 2.94, 3.22, 3.5 , 3.78, 4.06, 4.34, 4.62, 4.9 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### bar-plot

# %%
### what is the frequency table of book_table ? "Or"
## how many people prefer booking table & how many does not ??

# %%
df['rest_type'].unique()
# Out:
# array(['Casual Dining, Bar', 'Quick Bites', 'Bakery, Quick Bites', 'Pub',
#        'Casual Dining', 'Delivery', 'Beverage Shop, Dessert Parlor',
#        'Takeaway, Delivery', 'Beverage Shop', 'Cafe',
#        'Casual Dining, Microbrewery', 'Fine Dining, Bar', 'Food Court',
#        'Dessert Parlor', 'Beverage Shop, Quick Bites', 'Lounge',
#        'Casual Dining, Cafe', 'Quick Bites, Sweet Shop',
#        'Microbrewery, Casual Dining', 'Bar, Casual Dining', 'Sweet Shop',
#        'Dessert Parlor, Cafe', 'Sweet Shop, Quick Bites',
#        'Pub, Casual Dining', 'Bakery', 'Cafe, Dessert Parlor', 'Bar',
#        'Quick Bites, Beverage Shop', 'Casual Dining, Pub', 'Takeaway',
#        'Bakery, Cafe', 'Kiosk', 'Dessert Parlor, Quick Bites',
#        'Cafe, Bar', 'Quick Bites, Bakery', 'Mess', 'Cafe, Quick Bites',
#        'Fine Dining', 'Lounge, Bar', 'Quick Bites, Dessert Parlor',
#        'Cafe, Casual Dining', 'Quick Bites, Food Court',
# ...

# %%
df['book_table'].value_counts().values
# Out:
# array([4347,  653], dtype=int64)

# %%
plt.bar(x=df['book_table'].value_counts().index,
    height=df['book_table'].value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ### pie chart :

# %%
## what is pie chart ??

# %%
### A pie chart is a pictorial representation of data in the 
form of a circular chart or pie where the slices of the pie 
show the size of the data.

# %%
plt.pie(x=df['book_table'].value_counts().values , 
    labels=df['book_table'].value_counts().index)
## it returns Wedge shaped patch.

### if u want to get rid of additional stuffs ,
#then I say just show() the visual that u have

plt.show()

# %% [markdown]
# ### is there any relationsgip between rating & cost of food ?? (scatter)

# %%
plt.scatter(x="rate",y='approx_cost(for two people)',data=df)
plt.show()

# %% [markdown]
# ### use-case of line-chart (line-plot is typically
# used if u have to find trend within data) :

# %%
## imagine there is a feature as
dates=[]
total_orders=[]

plt.plot(dates,total_orders)

# %%
days=['sun','mon','tues','wed','thursday','fri','sat']
total_orders=[4000, 5056, 6598, 5499, 7897, 6789, 9012]

plt.plot(days,total_orders)

# %% [markdown]
# ## 5.styling in matplotlib

# %% [markdown]
# ### How to customize existing plots  ,ie changing colour of plots

# %%
### changing colour of plot
plt.scatter(x="rate",y='approx_cost(for two people)',
            data=df,c='g')
plt.show()

# %%
### changing marker-size
plt.scatter(x="rate",y='approx_cost(for two people)',
            data=df,c='g',s=10)
plt.show()

# %% [markdown]
# ### customizing width & bins in histogram

# %%
plt.hist(df['rate'])
# Out:
# (array([   4.,   57.,  154.,  396.,  443.,  995., 1054.,  673.,  238.,
#           39.]),
#  array([2.1 , 2.38, 2.66, 2.94, 3.22, 3.5 , 3.78, 4.06, 4.34, 4.62, 4.9 ]),
#  <BarContainer object of 10 artists>)

# %%
The towers or bars of a histogram are called bins 

The height of each bin shows how many values from 
                   that data fall into that range. 
    
The default value of the number of bins to be 
                created in a histogram is 10

As the bin size is changed so then the bin width 
                would be changed accordingly as :
Width of each bin is = 
(max value of data – min value of data) / total number of bins     
    
    
### bins = also called "intervals"  or "buckets".

# %%
plt.hist(df['rate'] ,bins=20)

###  if rate ,I need total 20 bars or 20 towers
# Out:
# (array([  2.,   2.,  19.,  38.,  75.,  79.,  81., 315., 196., 247., 590.,
#         405., 746., 308., 277., 396., 113., 125.,  23.,  16.]),
#  array([2.1 , 2.24, 2.38, 2.52, 2.66, 2.8 , 2.94, 3.08, 3.22, 3.36, 3.5 ,
#         3.64, 3.78, 3.92, 4.06, 4.2 , 4.34, 4.48, 4.62, 4.76, 4.9 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### How to set title ,xlabel & ylabel

# %%
plt.hist(df['rate'] ,bins=20)
plt.xlabel('Rating-bins')
plt.ylabel('rating count')
plt.show()

# %% [markdown]
# #### Problem statement : What are the most-famous restaurants in Bengalore ??

# %% [markdown]
# ### How to customize figure size , How to rotate axis values

# %%
plt.bar(x=df['rest_type'].value_counts().index,
        height=df['rest_type'].value_counts().values)
# Out:
# <BarContainer object of 61 artists>

# %%
plt.figure(figsize=(20,12))
plt.bar(x=df['rest_type'].value_counts().index,
        height=df['rest_type'].value_counts().values)
# Out:
# <BarContainer object of 61 artists>

# %%
plt.figure(figsize=(20,12))
plt.bar(x=df['rest_type'].value_counts().index,
        height=df['rest_type'].value_counts().values)
plt.gcf().autofmt_xdate()

## plt.gcf() -->> returns the current figure on 
                  which we are working
## autofmt_xdate() function is used to rotate 
                   them and right align them.

# %%
plt.figure(figsize=(20,12))
plt.bar(x=df['rest_type'].value_counts().index,
        height=df['rest_type'].value_counts().values)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.bar(x=df['rest_type'].value_counts().index,
        height=df['rest_type'].value_counts().values)
plt.xticks(rotation='vertical')

plt.xlabel('restaurant-type')
plt.ylabel('Count of restaurant')
plt.show()

# %% [markdown]
# ### How to set limit in x-axis & y-axis

# %%
plt.scatter(x="rate",y='approx_cost(for two people)',
            data=df,c='g')

# %%
### How to set limit in x-axis & y-axis
### what is the scatter-plot when only good 
     ratings are available :

plt.scatter(x="rate",y='approx_cost(for two people)',
              data=df,c='g')
plt.xlim(4.59,5.0)
plt.show()

## ie most of the highest rated rest are costly  ,
ofcourse few are in budget but most of them are in budget..

# %%
### How to set limit in x-axis & y-axis

plt.scatter(x="rate",y='approx_cost(for two people)',
            data=df,c='g')
plt.xlim(0,5.0)
plt.ylim(1500,3000)
plt.ylim()
plt.show()


### ie only highest rated rest are the costliest ones..

# %% [markdown]
# ### How to set legend on visuals ..
#    The legend tells us what each trend represents.

# %%
### histogram of ratings of different restaurant.. 
     ->> real world example..

# %%
### how to set legend

# %%
no=[1,2,3,4,5,6]
sq=[1,4,9,16,25,36]
cube=[1,8,27,64,125,216]

# %%
plt.plot(no,no)
plt.plot(no,sq)
plt.plot(no,cube)

plt.legend(["linear", "square",'cube'])

# %% [markdown]
# ## 6. Sub-plots in matplotlib

# %%
### use-case
## Rating distribution of hotels at 
    all the different locations..

# %%
### one is doing manually ,extract separate data 
     for each & do it.. (but not a optimal way)
### one is using subplots

# %%
df.head(2)
# Out:
#                               name online_order book_table  rate  votes  \
# 0  3B's - Buddies, Bar & Barbecues           No        Yes   NaN   1168
# 1                   New Taj Darbar           No         No   3.1      6
#
#      location           rest_type  \
# 0         BTM  Casual Dining, Bar
# 1  Whitefield         Quick Bites
#
#                                           dish_liked  \
# 0  Paan Ice Cream, Cocktails, Fish Grill, Crispy ...
# 1                                                NaN
#
#    approx_cost(for two people) listed_in(city)
# 0                       1100.0       Jayanagar
# 1                        300.0      Whitefield

# %%
df['location'].value_counts()
# Out:
# BTM                      1492
# Koramangala 5th Block     772
# HSR                       767
# JP Nagar                  708
# Whitefield                633
# Indiranagar               628
# Name: location, dtype: int64

# %% [markdown]
# ### using subplot

# %%
df['location'].unique()
# Out:
# array(['BTM', 'Whitefield', 'HSR', 'Koramangala 5th Block', 'JP Nagar',
#        'Indiranagar'], dtype=object)

# %%
loc_location=df['location'].unique()

# %%
plt.figure(figsize=(15, 7))
for index, loc in enumerate(loc_location, 1):
    plt.subplot(3, 2, index)
    data=df[df['location']==loc]
    plt.hist(data['rate'])
    plt.ylabel('count')
    plt.xlabel(loc)

# %% [markdown]
# ### plt.subplots( )
#      use-case->>
#      Imagine ,I need distribution-plot ,hisogram & boxplot of
#     any numerical feature ,here i can think of using this subplots
#
#
#       bcz instead of getting visuals in different cells ,
#       it is always good to get this in a same cells as
#       it makes things more easy for us..

# %%
df.head(2)
# Out:
#                               name online_order book_table  rate  votes  \
# 0  3B's - Buddies, Bar & Barbecues           No        Yes   NaN   1168
# 1                   New Taj Darbar           No         No   3.1      6
#
#      location           rest_type  \
# 0         BTM  Casual Dining, Bar
# 1  Whitefield         Quick Bites
#
#                                           dish_liked  \
# 0  Paan Ice Cream, Cocktails, Fish Grill, Crispy ...
# 1                                                NaN
#
#    approx_cost(for two people) listed_in(city)
# 0                       1100.0       Jayanagar
# 1                        300.0      Whitefield

# %%
###What are figure & axes

fig, (ax1,ax2,ax3)=plt.subplots(3,1,
                    figsize=(15,7))


ax1.hist(df['votes'])


ax2.hist(df['votes'],density=True)


ax3.boxplot(x=df['votes'])

plt.show()
